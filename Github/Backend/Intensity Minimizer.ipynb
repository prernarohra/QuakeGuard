# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
import dataprep
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv("Final Earthquake.csv")

# %%
df
# Out:
#       Magnitude  Depth  destruction  Victim's reaction  Intensity
# 0           7.1   40.0            6                  7          8
# 1           7.7   23.5            6                  7          8
# 2           7.7  196.0            4                  5          6
# 3           6.9   15.0            3                  4          5
# 4           6.9   51.6            4                  5          6
# ...         ...    ...          ...                ...        ...
# 9995        6.7   15.0            7                  8          9
# 9996        6.5   16.7            5                  6          7
# 9997        7.8   60.0            6                  7          8
# 9998        5.0   28.0            0                  1          2
# 9999        6.5    2.7            6                  7          8
#
# [10000 rows x 5 columns]

# %%
train_size = 0.6
num = int(len(df) * train_size)

train_data = df.sample(n=num, random_state=42)

train_data.to_csv("train_data.csv", index=False)

# %%
train_data
# Out:
#       Magnitude    Depth  destruction  Victim's reaction  Intensity
# 6252        6.9   93.000            4                  5          6
# 4684        7.0   73.000            5                  6          7
# 1731        6.9  205.681            3                  4          5
# 4742        5.7   10.000            5                  6          7
# 4521        5.5   10.000            6                  7          8
# ...         ...      ...          ...                ...        ...
# 7895        6.6   29.000            4                  5          6
# 9590        6.1    9.000            6                  7          8
# 7288        8.1   13.000            7                  8          9
# 278         7.4   20.000            6                  7          8
# 3252        7.5  126.000            6                  7          8
#
# [6000 rows x 5 columns]

# %%
test_size = 0.4
num = int(len(df) * test_size)

test_data = df.drop(train_data.index).sample(n=num, random_state=42)

test_data.to_csv("test_data.csv", index=False)

# %%
test_data
# Out:
#       Magnitude   Depth  destruction  Victim's reaction  Intensity
# 1500        7.1   35.00            5                  6          7
# 8800        7.3   10.00            7                  8          9
# 1401        5.5   33.00            2                  3          4
# 9822        6.7   24.00            5                  6          7
# 7553        6.8  219.96            2                  3          4
# ...         ...     ...          ...                ...        ...
# 2911        3.6   10.00            3                  4          5
# 3348        6.2   10.00            6                  7          8
# 2224        6.5   39.70            3                  4          5
# 8840        6.7  624.00            1                  2          3
# 7989        7.0   18.00            5                  6          7
#
# [4000 rows x 5 columns]

# %%
X = train_data.drop(columns=['Intensity'])
Y = train_data['Intensity']
x = test_data.drop(columns=['Intensity'])
y = test_data['Intensity']

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X)
x_test_scaled = scaler.transform(x)

# %%
X_train = X_train_scaled + np.random.normal(loc=0, scale=0.2, size=X_train_scaled.shape)
X_test = x_test_scaled + np.random.normal(loc=0, scale=0.2, size=x_test_scaled.shape)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, Y)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y, y_pred)
print("Test set accuracy:", accuracy)
# Out:
# Test set accuracy: 0.934

# %%
prediction = knn.predict(X_train)
accuracy = accuracy_score(Y, prediction)
print("Train Set Accuracy:", accuracy)
# Out:
# Train Set Accuracy: 0.9528333333333333

# %%
predictions = np.concatenate((prediction, y_pred))
labels = np.concatenate((Y, y))

overall_accuracy = accuracy_score(labels, predictions)
print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9453

# %%
report = classification_report(y, y_pred)

print("\nClassification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67         1
#            2       0.93      0.74      0.82        19
#            3       0.93      0.94      0.94       102
#            4       0.96      0.94      0.95       298
#            5       0.93      0.93      0.93       469
#            6       0.94      0.94      0.94       796
#            7       0.94      0.95      0.95       943
#            8       0.94      0.93      0.93       617
#            9       0.92      0.94      0.93       440
#           10       0.92      0.90      0.91       249
#           11       0.80      0.90      0.85        52
#           12       0.90      0.64      0.75        14
#
#     accuracy                           0.93      4000
#    macro avg       0.88      0.90      0.88      4000
# weighted avg       0.93      0.93      0.93      4000

# %%
input_parameters = [
    5.6,  # Magnitude
    153,  # Depth(km)
    4,   # Destruction
    5   # Victim's Reaction
]
input_parameters = [input_parameters]
input_parameters_scaled = scaler.transform(input_parameters)
predicted_intensity = knn.predict(input_parameters_scaled)
print(f"Predicted Intensity: {predicted_intensity[0]}")
# Out:
# Predicted Intensity: 6
# C:\Users\Prern\anaconda3\envs\Mine\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#Three standards 
Reduced_Intensity = predicted_intensity[0]/2
roundoff = round(Reduced_Intensity)
print(f"Reduced Intensity: {roundoff}")
print("We suggest you to use these combined standards on tall and high budget buildings")
# Out:
# Reduced Intensity: 3
# We suggest you to use these combined standards on tall and high budget buildings

# %%
#seishen
Reduced_Intensity = predicted_intensity[0]*0.70
roundoff = round(Reduced_Intensity)
print(f"Reduced Intensity: {roundoff}")
# Out:
# Reduced Intensity: 4

# %%
#Menshin
building = input("Enter your building size: ")
if building=="Tall" or "tall":
    Reduced_Intensity = predicted_intensity[0]/5
    roundoff = round(Reduced_Intensity)
    print(f"Reduced Intensity: {roundoff}")
elif building=="Medium" or "medium":
    Reduced_Intensity = predicted_intensity[0]/3
    roundoff = round(Reduced_Intensity)
    print(f"Reduced Intensity: {roundoff}")
else: 
    print('''we won't suggest you to use this standard on small building, because for that it will get much expensive and small
    building doesn't need this standards, taishin is enough for that''')
# Out:
# Enter your building size: tall
# Reduced Intensity: 1
